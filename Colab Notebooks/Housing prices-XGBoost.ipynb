# %% [markdown]
# # New Section

# %%
import pandas as pd


df = pd.read_csv("/content/train.csv")
test = pd.read_csv("/content/test.csv")

# %%
nan_cols = [i for i in df. columns if df[i]. isnull(). any()]

# %%
nan_cols
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
nan_indices = df.columns[df.isna().any()].tolist()

# %%
nans = df.loc[:,nan_indices]

# %%
nans
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0            65.0   NaN    BrkFace       196.0       Gd       TA           No
# 1            80.0   NaN       None         0.0       Gd       TA           Gd
# 2            68.0   NaN    BrkFace       162.0       Gd       TA           Mn
# 3            60.0   NaN       None         0.0       TA       Gd           No
# 4            84.0   NaN    BrkFace       350.0       Gd       TA           Av
# ...           ...   ...        ...         ...      ...      ...          ...
# 1455         62.0   NaN       None         0.0       Gd       TA           No
# 1456         85.0   NaN      Stone       119.0       Gd       TA           No
# 1457         66.0   NaN       None         0.0       TA       Gd           No
# 1458         68.0   NaN       None         0.0       TA       TA           Mn
# 1459         75.0   NaN       None         0.0       TA       TA           No
#
# ...

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
s= (df.dtypes=="object")
object_cols = list(s[s].index)
object_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
DataFrame=df

# %%
df[object_cols].isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df[object_cols]= df[object_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
le = LabelEncoder()
df[object_cols]= df[object_cols].apply(le.fit_transform)

# %%
nan_indices = df.columns[df.isna().any()].tolist()

# %%
nan_indices
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
LotCorr=df.corrwith(df['LotFrontage'])

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
sns.scatterplot(df,x="SalePrice", y="LotFrontage")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-e49441ae2acf> in <module>
# ----> 1 sns.scatterplot(df,x="SalePrice", y="LotFrontage")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     810         x_bins=x_bins, y_bins=y_bins,
#     811         estimator=estimator, ci=ci, n_boot=n_boot,
# ...

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median())
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
sns.distplot(df["SalePrice"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['MasVnrArea'].fillna(df['MasVnrArea'].mean())
# Out:
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0
#         ...
# 1455      0.0
# 1456    119.0
# 1457      0.0
# 1458      0.0
# 1459      0.0
# Name: MasVnrArea, Length: 1460, dtype: float64

# %%
df["GarageYrBlt"].fillna(df["GarageYrBlt"].mean())
# Out:
# 0       2003.0
# 1       1976.0
# 2       2001.0
# 3       1998.0
# 4       2000.0
#          ...
# 1455    1999.0
# 1456    1978.0
# 1457    1941.0
# 1458    1950.0
# 1459    1965.0
# Name: GarageYrBlt, Length: 1460, dtype: float64

# %%
import xgboost as xgb

# %%
y_pred = df['SalePrice']

# %%
x_train=df.drop(["SalePrice"],axis=1,inplace=True)

# %%
x_train = df

# %%
y_train = y_pred

# %%
x_pred= test

# %%
xgb_model = xgb.XGBRegressor(max_depth=3, learning_rate=0.1, n_estimators=100, verbosity=1, objective='reg:linear', booster='gbtree')

# %%
xgb_model.fit(x_train,y_train)
# Out:
# [07:25:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
x_pred[object_cols]= x_pred[object_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
l = LabelEncoder()
x_pred[object_cols]= x_pred[object_cols].apply(l.fit_transform)

# %%
nan_indices = x_pred.columns[x_pred.isna().any()].tolist()

# %%
nan_indices
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
for i in nan_indices:
  x_pred[i]=x_pred[i].fillna(x_pred[i].mean())

# %%
xgb_model.fit(x_train,y_train)
# Out:
# [07:25:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
x_pred.
# Out:
#   File "<ipython-input-38-a47fab17a189>", line 1
#     x_pred.
#            ^
# SyntaxError: invalid syntax

# %%
y_pred = xgb_model.predict(x_pred)

# %%
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error

# %%
y_pred.shape
