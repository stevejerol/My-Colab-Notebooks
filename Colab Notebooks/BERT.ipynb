# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 15.3 MB/s
# ...
#      |████████████████████████████████| 182 kB 67.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 81.3 MB/s
# ...

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='bert-base-uncased')
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
unmasker("Artificial Intelligence will make humans their [MASK].")
# Out:
# [{'score': 0.18437613546848297,
#   'token': 6716,
#   'token_str': 'enemies',
#   'sequence': 'artificial intelligence will make humans their enemies.'},
#  {'score': 0.07870692014694214,
#   'token': 4099,
#   'token_str': 'enemy',
#   'sequence': 'artificial intelligence will make humans their enemy.'},
#  {'score': 0.06897436827421188,
#   'token': 2219,
#   'token_str': 'own',
#   'sequence': 'artificial intelligence will make humans their own.'},
#  {'score': 0.04947413504123688,
#   'token': 7179,
#   'token_str': 'slaves',
#   'sequence': 'artificial intelligence will make humans their slaves.'},
#  {'score': 0.039356667548418045,
#   'token': 8336,
#   'token_str': 'prey',
#   'sequence': 'artificial intelligence will make humans their prey.'}]
